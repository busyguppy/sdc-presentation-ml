# %%
from mp3tagger.training.tools import preprocessing, load_data
import keras
from keras import layers
# Out:
# Using TensorFlow backend.

# %%
def baseline_model():
    inputs = keras.Input(shape=(14,), name='features')
    x = layers.Dense(10, activation='sigmoid', name='dense_1')(inputs)
    outputs = layers.Dense(3, activation='softmax', name='predictions')(x)
    four_layer = keras.Model(inputs=inputs, outputs=outputs)
    four_layer.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return four_layer

# %%
df = load_data()
df = preprocessing(df)

# %%
df.shape
# Out:
# (22531, 14)

# %%
df
# Out:
#        tag   str  i_seg  str_len_left  seg_len  left_lo_seg_cnt  title_len  \
# 0        4  1399      0             0       15                0         65
# 1       13    15      1            15        1                0         65
# 2       13    15      2            16        1                0         65
# 3       13    15      3            17        1                0         65
# 4       18     0      4            18        1                0         65
# ...    ...   ...    ...           ...      ...              ...        ...
# 22526    9    14      5            16        1                2         27
# 22527    7    39      6            17        7                2         27
# 22528   18     0      7            24        1                2         27
# 22529   16  5095      8            25        1                2         27
# 22530   18     0      9            26        1                2         27
#
# ...

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import KFold, cross_val_score
from keras import Sequential
from keras.layers import Dense

estimator = KerasClassifier(build_fn=baseline_model, epochs=1, batch_size=1000, verbose=0)
kfold = KFold(n_splits=10, shuffle=True)

results = cross_val_score(estimator, df.values[:, 0:14], df.values[:,13], cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean() * 100, results.std() * 100))
# Out:
# Baseline: 57.85% (18.66%)

# %%
results
# Out:
# array([0.70674354, 0.48601863, 0.42920551, 0.12738571, 0.71282732,
#        0.73235685, 0.4864625 , 0.72924989, 0.70572567, 0.66888595])
